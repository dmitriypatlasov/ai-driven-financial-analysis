# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import keras
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, Dropout, BatchNormalization, Activation
from keras.models import Model, Sequential
from keras.regularizers import l1_l2
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler, Normalizer, PowerTransformer
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.ensemble import IsolationForest
import tensorflow as tf
from sklearn.preprocessing import PowerTransformer
from keras.regularizers import l1_l2

import warnings
warnings.filterwarnings("ignore")

np.random.seed(42)
# Out:
# 2024-06-12 19:12:49.933215: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-12 19:12:50.551844: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
volatility_df = pd.read_csv('volatility_df.csv', 
                     parse_dates=['Date'], index_col='Date')

# %%
plot_values = volatility_df['Realized_Volatility']

train_size = int(len(plot_values) * 0.7)
val_size = int(len(plot_values) * 0.15)
test_size = len(plot_values) - train_size - val_size

train_sample = plot_values.iloc[:train_size]
val_sample = plot_values.iloc[train_size:train_size + val_size]
test_sample = plot_values.iloc[train_size + val_size:]

plt.figure(figsize=(10, 4))
plt.plot(train_sample, color='green', label='Обучающая выборка')
plt.plot(val_sample, color='red', label='Валидационная выборка')
plt.plot(test_sample, color='cyan', label='Тестовая выборка')
plt.xlabel('Дата')
plt.ylabel('S&P 500 Релизованная волатильность')
plt.legend()

plt.savefig('train_val_test.svg', format='svg', dpi=1200)

plt.show()

# %%
volatility_df = volatility_df[['Recovered_vol', 'Realized_Volatility']]

volatility_df = volatility_df.replace([0], 1e-6)

volatility_df = volatility_df / volatility_df.shift(1) - 1

lag = -5
volatility_df[f'Realized_Volatility_(t+{abs(lag)})'] = volatility_df['Realized_Volatility'].shift(lag)
volatility_df = volatility_df.dropna()
volatility_df.drop('Realized_Volatility', axis=1, inplace=True)
print(len(volatility_df))
volatility_df.head(10)
# Out:
# 3357
#             Recovered_vol  Realized_Volatility_(t+5)
# Date
# 2010-01-05      -0.024188                   0.031692
# 2010-01-06       0.001425                   0.029962
# 2010-01-07       0.007015                  -0.022161
# 2010-01-08       0.030061                   0.046408
# 2010-01-11       0.030583                   0.073188
# 2010-01-12      -0.037054                  -0.011969
# 2010-01-13       0.161288                   0.137014
# 2010-01-14       0.012751                   0.125819
# 2010-01-15      -0.231002                   0.002256
# 2010-01-19       0.041342                   0.003335

# %%
# Стандартизация, нормализация, замена выбросов медианой

values_clear = volatility_df.copy()

train_size = int(len(values_clear) * 0.7)
val_size = int(len(values_clear) * 0.15)
test_size = len(values_clear) - train_size - val_size

train = values_clear.iloc[:train_size]
val = values_clear.iloc[train_size:train_size + val_size]
test = values_clear.iloc[train_size + val_size:]

# Обучаем стандартизатор, нормализатор и изолейшн форест на тренировочных данных
transformer = PowerTransformer(method='yeo-johnson')
transformer.fit(train)
train_transformed = transformer.transform(train)

scaler = MinMaxScaler(feature_range=(1e-6, 1))
scaler.fit(train_transformed)
train_scaled = scaler.transform(train_transformed)

isolation_forest = IsolationForest(n_estimators=1000, contamination=0.01, random_state=42) # 0.01
isolation_forest.fit(train_scaled)

normalizer = Normalizer()
normalizer.fit(train_scaled)

# Применяем стандартизатор, нормализатор и изолейшн форест на тренировочных, валидационных и тестовых данных
train_isolation_forest = isolation_forest.predict(train_scaled)
train_normalized = normalizer.transform(train_scaled)

val_transformed = transformer.transform(val)
val_scaled = scaler.transform(val_transformed)
val_isolation_forest = isolation_forest.predict(val_scaled)
val_normalized = normalizer.transform(val_scaled)

test_transformed = transformer.transform(test)
test_scaled = scaler.transform(test_transformed)
test_isolation_forest = isolation_forest.predict(test_scaled)
test_normalized = normalizer.transform(test_scaled)

# Считаем метрику
train_values = np.median(train_normalized, axis=0)
val_values = np.median(val_normalized, axis=0)
test_values = np.median(test_normalized, axis=0)

# Заполняем выбросы медианой
train_normalized[train_isolation_forest == -1] = train_values
val_normalized[val_isolation_forest == -1] = val_values
test_normalized[test_isolation_forest == -1] = test_values

y_train = train_normalized[:, -1:]
y_train = np.squeeze(y_train)
X_train = np.delete(train_normalized, -1, axis=1)

y_val = val_normalized[:, -1:]
y_val = np.squeeze(y_val)
X_val = np.delete(val_normalized, -1, axis=1)

y_test = test_normalized[:, -1:]
y_test = np.squeeze(y_test)
X_test = np.delete(test_normalized, -1, axis=1)

# Reshape
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_val = X_val.reshape((X_val.shape[0], 1, X_val.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

print(X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape)
# Out:
# (2349, 1, 1) (2349,) (503, 1, 1) (503,) (505, 1, 1) (505,)

# %%
# LSTM

# %%
# custom_logcosh

penalty = 5
quantile_threshold = 75
quantile = tf.constant(np.percentile(y_train, quantile_threshold), dtype=tf.float32)

def custom_logcosh(y_true, y_pred):
    error = y_true - y_pred
    mask = tf.cast(y_true > quantile, tf.float32)
    weighted_error = error * (1 + penalty * mask * (y_true - quantile))
    return tf.reduce_sum(tf.math.log(tf.math.cosh(weighted_error)))

# %%
n_units = 4
dropout_rate = 0.0
recurrent_dropout_rate = 0.0
activation = 'tanh'
seed = 1
input_model = (X_train.shape[1], X_train.shape[2])

model = Sequential()

model.add(LSTM(
    n_units,
    activation=activation, 
    return_sequences=True,
    input_shape=input_model,
    recurrent_dropout=recurrent_dropout_rate,
    seed=seed,
))
model.add(Dropout(dropout_rate))

model.add(LSTM(
    n_units,
    activation=activation,
    return_sequences=True,
    recurrent_dropout=recurrent_dropout_rate,
    seed=seed
))
model.add(Dropout(dropout_rate))

model.add(LSTM(
    n_units,
    activation=activation,
    recurrent_dropout=recurrent_dropout_rate,
    seed=seed
))
model.add(Dropout(dropout_rate))

model.add(Dense(1))
model.add(Activation('linear'))

early_stopping = EarlyStopping(monitor='val_loss', patience=5)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=custom_logcosh) # keras.losses.log_cosh

history = model.fit(X_train,
                    y_train,
                    epochs=500,
                    batch_size=4,
                    validation_data=(X_val, y_val),
                    verbose=1,
                    shuffle=False,
                    callbacks=[early_stopping])

# Предсказание значений на валидационной выборке
val_pred = model.predict(X_val)
print(f'MSE val: {mean_squared_error(y_val, val_pred):.4f}')
print(f'MAE val: {mean_absolute_error(y_val, val_pred):.4f}')
print(f'R2 val: {r2_score(y_val, val_pred):.4f}')
print(f'MAPE val: {mean_absolute_percentage_error(y_val, val_pred):.4f}')

# Предсказание значений на тестовой выборке
y_pred = model.predict(X_test)
print(f'MSE test: {mean_squared_error(y_test, y_pred):.4f}')
print(f'MAE test: {mean_absolute_error(y_test, y_pred):.4f}')
print(f'R2 test: {r2_score(y_test, y_pred):.4f}')
print(f'MAPE test: {mean_absolute_percentage_error(y_test, y_pred):.4f}')
# Out:
# Epoch 1/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.9534 - val_loss: 0.7217
# Epoch 2/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.6312 - val_loss: 0.3187
# Epoch 3/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2273 - val_loss: 0.0326
# Epoch 4/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0198 - val_loss: 0.0059
# Epoch 5/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0069 - val_loss: 0.0058
# Epoch 6/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0069 - val_loss: 0.0058
# Epoch 7/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0068 - val_loss: 0.0058
# Epoch 8/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0068 - val_loss: 0.0057
# Epoch 9/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0067 - val_loss: 0.0057
# Epoch 10/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0067 - val_loss: 0.0056
# Epoch 11/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0066 - val_loss: 0.0055
# Epoch 12/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0065 - val_loss: 0.0055
# Epoch 13/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0065 - val_loss: 0.0054
# Epoch 14/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0064 - val_loss: 0.0054
# Epoch 15/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0063 - val_loss: 0.0053
# Epoch 16/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0062 - val_loss: 0.0052
# Epoch 17/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0062 - val_loss: 0.0052
# Epoch 18/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0061 - val_loss: 0.0051
# Epoch 19/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0061 - val_loss: 0.0051
# Epoch 20/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0060 - val_loss: 0.0050
# Epoch 21/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0059 - val_loss: 0.0050
# Epoch 22/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 23/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 24/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 25/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 26/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 27/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0056 - val_loss: 0.0047
# Epoch 28/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0056 - val_loss: 0.0047
# Epoch 29/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0055 - val_loss: 0.0047
# Epoch 30/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0055 - val_loss: 0.0046
# Epoch 31/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0055 - val_loss: 0.0046
# Epoch 32/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0054 - val_loss: 0.0046
# Epoch 33/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0054 - val_loss: 0.0045
# Epoch 34/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 35/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 36/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0053 - val_loss: 0.0044
# Epoch 37/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0052 - val_loss: 0.0044
# Epoch 38/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0052 - val_loss: 0.0044
# Epoch 39/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0052 - val_loss: 0.0044
# Epoch 40/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0051 - val_loss: 0.0043
# Epoch 41/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0051 - val_loss: 0.0043
# Epoch 42/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0051 - val_loss: 0.0043
# Epoch 43/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 44/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 45/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 46/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0049 - val_loss: 0.0042
# Epoch 47/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0049 - val_loss: 0.0041
# Epoch 48/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0049 - val_loss: 0.0041
# Epoch 49/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0049 - val_loss: 0.0041
# Epoch 50/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0048 - val_loss: 0.0041
# Epoch 51/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0048 - val_loss: 0.0040
# Epoch 52/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0048 - val_loss: 0.0040
# Epoch 53/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 54/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 55/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 56/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 57/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 58/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 59/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 60/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 61/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 62/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 63/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0043 - val_loss: 0.0036
# Epoch 64/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0042 - val_loss: 0.0036
# Epoch 65/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0042 - val_loss: 0.0035
# Epoch 66/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0041 - val_loss: 0.0034
# Epoch 67/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0040 - val_loss: 0.0034
# Epoch 68/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0040 - val_loss: 0.0033
# Epoch 69/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0039 - val_loss: 0.0032
# Epoch 70/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0038 - val_loss: 0.0031
# Epoch 71/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 72/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 73/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 74/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 75/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 76/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 77/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 78/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 79/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 80/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 81/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 82/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 83/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0013 - val_loss: 9.1683e-04
# Epoch 84/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0010 - val_loss: 7.1270e-04
# Epoch 85/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.1318e-04 - val_loss: 5.2795e-04
# Epoch 86/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.0339e-04 - val_loss: 3.7007e-04
# Epoch 87/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.2677e-04 - val_loss: 2.4599e-04
# Epoch 88/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.9024e-04 - val_loss: 1.6045e-04
# Epoch 89/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.9694e-04 - val_loss: 1.1265e-04
# Epoch 90/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.4305e-04 - val_loss: 9.2309e-05
# Epoch 91/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.1711e-04 - val_loss: 8.5093e-05
# Epoch 92/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0595e-04 - val_loss: 8.2235e-05
# Epoch 93/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0099e-04 - val_loss: 8.0617e-05
# Epoch 94/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.8438e-05 - val_loss: 7.9424e-05
# Epoch 95/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.6827e-05 - val_loss: 7.8458e-05
# Epoch 96/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.5631e-05 - val_loss: 7.7640e-05
# Epoch 97/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.4632e-05 - val_loss: 7.6920e-05
# Epoch 98/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.3743e-05 - val_loss: 7.6279e-05
# Epoch 99/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.2908e-05 - val_loss: 7.5715e-05
# Epoch 100/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.2109e-05 - val_loss: 7.5180e-05
# Epoch 101/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.1333e-05 - val_loss: 7.4646e-05
# Epoch 102/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.0573e-05 - val_loss: 7.4168e-05
# Epoch 103/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.9818e-05 - val_loss: 7.3670e-05
# Epoch 104/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.9068e-05 - val_loss: 7.3196e-05
# Epoch 105/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.8338e-05 - val_loss: 7.2717e-05
# Epoch 106/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.7604e-05 - val_loss: 7.2264e-05
# Epoch 107/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.6878e-05 - val_loss: 7.1782e-05
# Epoch 108/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.6164e-05 - val_loss: 7.1335e-05
# Epoch 109/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.5450e-05 - val_loss: 7.0870e-05
# Epoch 110/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.4730e-05 - val_loss: 7.0414e-05
# Epoch 111/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.4032e-05 - val_loss: 6.9960e-05
# Epoch 112/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.3323e-05 - val_loss: 6.9498e-05
# Epoch 113/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.2626e-05 - val_loss: 6.9051e-05
# Epoch 114/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.1931e-05 - val_loss: 6.8621e-05
# Epoch 115/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.1245e-05 - val_loss: 6.8165e-05
# Epoch 116/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.0558e-05 - val_loss: 6.7715e-05
# Epoch 117/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.9876e-05 - val_loss: 6.7286e-05
# Epoch 118/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.9201e-05 - val_loss: 6.6830e-05
# Epoch 119/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.8521e-05 - val_loss: 6.6398e-05
# Epoch 120/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.7854e-05 - val_loss: 6.5969e-05
# Epoch 121/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.7185e-05 - val_loss: 6.5518e-05
# Epoch 122/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.6528e-05 - val_loss: 6.5091e-05
# Epoch 123/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.5865e-05 - val_loss: 6.4672e-05
# Epoch 124/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.5217e-05 - val_loss: 6.4220e-05
# Epoch 125/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.4573e-05 - val_loss: 6.3812e-05
# Epoch 126/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.3921e-05 - val_loss: 6.3390e-05
# Epoch 127/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.3280e-05 - val_loss: 6.2944e-05
# Epoch 128/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.2642e-05 - val_loss: 6.2522e-05
# Epoch 129/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.2007e-05 - val_loss: 6.2117e-05
# Epoch 130/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.1377e-05 - val_loss: 6.1703e-05
# Epoch 131/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.0745e-05 - val_loss: 6.1258e-05
# Epoch 132/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 7.0134e-05 - val_loss: 6.0873e-05
# Epoch 133/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.9515e-05 - val_loss: 6.0430e-05
# Epoch 134/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.8892e-05 - val_loss: 6.0019e-05
# Epoch 135/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.8284e-05 - val_loss: 5.9630e-05
# Epoch 136/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.7672e-05 - val_loss: 5.9213e-05
# Epoch 137/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.7064e-05 - val_loss: 5.8794e-05
# Epoch 138/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.6465e-05 - val_loss: 5.8402e-05
# Epoch 139/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.5869e-05 - val_loss: 5.7993e-05
# Epoch 140/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.5274e-05 - val_loss: 5.7594e-05
# Epoch 141/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.4677e-05 - val_loss: 5.7204e-05
# Epoch 142/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.4090e-05 - val_loss: 5.6804e-05
# Epoch 143/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.3505e-05 - val_loss: 5.6400e-05
# Epoch 144/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.2915e-05 - val_loss: 5.6008e-05
# Epoch 145/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.2345e-05 - val_loss: 5.5606e-05
# Epoch 146/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.1770e-05 - val_loss: 5.5199e-05
# Epoch 147/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.1202e-05 - val_loss: 5.4838e-05
# Epoch 148/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.0636e-05 - val_loss: 5.4438e-05
# Epoch 149/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 6.0058e-05 - val_loss: 5.4051e-05
# Epoch 150/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.9500e-05 - val_loss: 5.3675e-05
# Epoch 151/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.8943e-05 - val_loss: 5.3294e-05
# Epoch 152/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.8382e-05 - val_loss: 5.2916e-05
# Epoch 153/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.7833e-05 - val_loss: 5.2542e-05
# Epoch 154/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.7281e-05 - val_loss: 5.2159e-05
# Epoch 155/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.6726e-05 - val_loss: 5.1788e-05
# Epoch 156/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.6187e-05 - val_loss: 5.1433e-05
# Epoch 157/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.5648e-05 - val_loss: 5.1061e-05
# Epoch 158/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.5107e-05 - val_loss: 5.0684e-05
# Epoch 159/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.4572e-05 - val_loss: 5.0336e-05
# Epoch 160/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.4036e-05 - val_loss: 4.9963e-05
# Epoch 161/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.3511e-05 - val_loss: 4.9620e-05
# Epoch 162/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.2993e-05 - val_loss: 4.9257e-05
# Epoch 163/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.2464e-05 - val_loss: 4.8900e-05
# Epoch 164/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.1944e-05 - val_loss: 4.8557e-05
# Epoch 165/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.1418e-05 - val_loss: 4.8214e-05
# Epoch 166/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.0913e-05 - val_loss: 4.7850e-05
# Epoch 167/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.0399e-05 - val_loss: 4.7539e-05
# Epoch 168/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.9888e-05 - val_loss: 4.7178e-05
# Epoch 169/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.9390e-05 - val_loss: 4.6856e-05
# Epoch 170/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.8875e-05 - val_loss: 4.6531e-05
# Epoch 171/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.8378e-05 - val_loss: 4.6200e-05
# Epoch 172/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.7890e-05 - val_loss: 4.5892e-05
# Epoch 173/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.7391e-05 - val_loss: 4.5554e-05
# Epoch 174/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.6902e-05 - val_loss: 4.5231e-05
# Epoch 175/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.6424e-05 - val_loss: 4.4918e-05
# Epoch 176/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.5927e-05 - val_loss: 4.4612e-05
# Epoch 177/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.5440e-05 - val_loss: 4.4302e-05
# Epoch 178/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.4962e-05 - val_loss: 4.4017e-05
# Epoch 179/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.4488e-05 - val_loss: 4.3708e-05
# Epoch 180/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.4010e-05 - val_loss: 4.3396e-05
# Epoch 181/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.3543e-05 - val_loss: 4.3110e-05
# Epoch 182/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.3074e-05 - val_loss: 4.2799e-05
# Epoch 183/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.2602e-05 - val_loss: 4.2540e-05
# Epoch 184/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.2134e-05 - val_loss: 4.2256e-05
# Epoch 185/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.1678e-05 - val_loss: 4.1981e-05
# Epoch 186/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.1218e-05 - val_loss: 4.1684e-05
# Epoch 187/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.0764e-05 - val_loss: 4.1431e-05
# Epoch 188/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.0309e-05 - val_loss: 4.1157e-05
# Epoch 189/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.9860e-05 - val_loss: 4.0900e-05
# Epoch 190/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.9412e-05 - val_loss: 4.0640e-05
# Epoch 191/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.8969e-05 - val_loss: 4.0380e-05
# Epoch 192/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.8526e-05 - val_loss: 4.0141e-05
# Epoch 193/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.8088e-05 - val_loss: 3.9872e-05
# Epoch 194/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.7647e-05 - val_loss: 3.9628e-05
# Epoch 195/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.7214e-05 - val_loss: 3.9374e-05
# Epoch 196/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.6777e-05 - val_loss: 3.9137e-05
# Epoch 197/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.6346e-05 - val_loss: 3.8894e-05
# Epoch 198/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.5923e-05 - val_loss: 3.8669e-05
# Epoch 199/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.5494e-05 - val_loss: 3.8432e-05
# Epoch 200/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.5075e-05 - val_loss: 3.8203e-05
# Epoch 201/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.4656e-05 - val_loss: 3.7986e-05
# Epoch 202/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.4240e-05 - val_loss: 3.7738e-05
# Epoch 203/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.3826e-05 - val_loss: 3.7537e-05
# Epoch 204/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.3411e-05 - val_loss: 3.7320e-05
# Epoch 205/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.2999e-05 - val_loss: 3.7093e-05
# Epoch 206/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.2592e-05 - val_loss: 3.6878e-05
# Epoch 207/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.2183e-05 - val_loss: 3.6640e-05
# Epoch 208/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.1783e-05 - val_loss: 3.6441e-05
# Epoch 209/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.1389e-05 - val_loss: 3.6233e-05
# Epoch 210/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.0985e-05 - val_loss: 3.6009e-05
# Epoch 211/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.0586e-05 - val_loss: 3.5795e-05
# Epoch 212/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.0191e-05 - val_loss: 3.5563e-05
# Epoch 213/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.9797e-05 - val_loss: 3.5365e-05
# Epoch 214/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.9408e-05 - val_loss: 3.5147e-05
# Epoch 215/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.9027e-05 - val_loss: 3.4922e-05
# Epoch 216/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.8636e-05 - val_loss: 3.4734e-05
# Epoch 217/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.8248e-05 - val_loss: 3.4484e-05
# Epoch 218/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.7872e-05 - val_loss: 3.4262e-05
# Epoch 219/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.7494e-05 - val_loss: 3.4035e-05
# Epoch 220/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.7112e-05 - val_loss: 3.3802e-05
# Epoch 221/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.6730e-05 - val_loss: 3.3557e-05
# Epoch 222/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.6365e-05 - val_loss: 3.3347e-05
# Epoch 223/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.5993e-05 - val_loss: 3.3083e-05
# Epoch 224/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5621e-05 - val_loss: 3.2829e-05
# Epoch 225/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.5251e-05 - val_loss: 3.2575e-05
# Epoch 226/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.4875e-05 - val_loss: 3.2313e-05
# Epoch 227/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.4519e-05 - val_loss: 3.2060e-05
# Epoch 228/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.4150e-05 - val_loss: 3.1770e-05
# Epoch 229/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.3793e-05 - val_loss: 3.1478e-05
# Epoch 230/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.3440e-05 - val_loss: 3.1209e-05
# Epoch 231/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.3078e-05 - val_loss: 3.0903e-05
# Epoch 232/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.2722e-05 - val_loss: 3.0590e-05
# Epoch 233/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.2367e-05 - val_loss: 3.0259e-05
# Epoch 234/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.2020e-05 - val_loss: 2.9952e-05
# Epoch 235/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.1664e-05 - val_loss: 2.9612e-05
# Epoch 236/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.1318e-05 - val_loss: 2.9260e-05
# Epoch 237/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.0969e-05 - val_loss: 2.8899e-05
# Epoch 238/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.0622e-05 - val_loss: 2.8529e-05
# Epoch 239/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.0281e-05 - val_loss: 2.8146e-05
# Epoch 240/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.9927e-05 - val_loss: 2.7737e-05
# Epoch 241/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.9584e-05 - val_loss: 2.7326e-05
# Epoch 242/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.9249e-05 - val_loss: 2.6923e-05
# Epoch 243/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8905e-05 - val_loss: 2.6497e-05
# Epoch 244/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8567e-05 - val_loss: 2.6037e-05
# Epoch 245/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8237e-05 - val_loss: 2.5595e-05
# Epoch 246/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7899e-05 - val_loss: 2.5140e-05
# Epoch 247/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7561e-05 - val_loss: 2.4630e-05
# Epoch 248/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7234e-05 - val_loss: 2.4175e-05
# Epoch 249/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6901e-05 - val_loss: 2.3648e-05
# Epoch 250/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6578e-05 - val_loss: 2.3154e-05
# Epoch 251/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6245e-05 - val_loss: 2.2649e-05
# Epoch 252/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5924e-05 - val_loss: 2.2108e-05
# Epoch 253/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5603e-05 - val_loss: 2.1574e-05
# Epoch 254/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5279e-05 - val_loss: 2.1036e-05
# Epoch 255/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.4963e-05 - val_loss: 2.0471e-05
# Epoch 256/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.4651e-05 - val_loss: 1.9951e-05
# Epoch 257/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.4334e-05 - val_loss: 1.9388e-05
# Epoch 258/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.4011e-05 - val_loss: 1.8856e-05
# Epoch 259/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.3709e-05 - val_loss: 1.8283e-05
# Epoch 260/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.3399e-05 - val_loss: 1.7712e-05
# Epoch 261/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.3096e-05 - val_loss: 1.7164e-05
# Epoch 262/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.2794e-05 - val_loss: 1.6604e-05
# Epoch 263/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.2487e-05 - val_loss: 1.6057e-05
# Epoch 264/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.2195e-05 - val_loss: 1.5505e-05
# Epoch 265/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.1907e-05 - val_loss: 1.4958e-05
# Epoch 266/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.1612e-05 - val_loss: 1.4441e-05
# Epoch 267/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.1321e-05 - val_loss: 1.3900e-05
# Epoch 268/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.1032e-05 - val_loss: 1.3384e-05
# Epoch 269/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0748e-05 - val_loss: 1.2850e-05
# Epoch 270/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0474e-05 - val_loss: 1.2356e-05
# Epoch 271/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0201e-05 - val_loss: 1.1846e-05
# Epoch 272/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.9262e-06 - val_loss: 1.1340e-05
# Epoch 273/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.6640e-06 - val_loss: 1.0881e-05
# Epoch 274/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.4005e-06 - val_loss: 1.0403e-05
# Epoch 275/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.1327e-06 - val_loss: 9.9306e-06
# Epoch 276/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.8742e-06 - val_loss: 9.4839e-06
# Epoch 277/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.6261e-06 - val_loss: 9.0315e-06
# Epoch 278/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.3791e-06 - val_loss: 8.5556e-06
# Epoch 279/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8.1322e-06 - val_loss: 8.1335e-06
# Epoch 280/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.8933e-06 - val_loss: 7.7104e-06
# Epoch 281/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.6537e-06 - val_loss: 7.2836e-06
# Epoch 282/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.4120e-06 - val_loss: 6.8362e-06
# Epoch 283/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.1896e-06 - val_loss: 6.4321e-06
# Epoch 284/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.9677e-06 - val_loss: 6.0451e-06
# Epoch 285/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.7448e-06 - val_loss: 5.6590e-06
# Epoch 286/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.5279e-06 - val_loss: 5.2926e-06
# Epoch 287/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.3269e-06 - val_loss: 4.9103e-06
# Epoch 288/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.1130e-06 - val_loss: 4.5555e-06
# Epoch 289/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.9098e-06 - val_loss: 4.2024e-06
# Epoch 290/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.7159e-06 - val_loss: 3.8912e-06
# Epoch 291/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.5143e-06 - val_loss: 3.5895e-06
# Epoch 292/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.3266e-06 - val_loss: 3.2933e-06
# Epoch 293/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.1402e-06 - val_loss: 3.0125e-06
# Epoch 294/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.9645e-06 - val_loss: 2.7238e-06
# Epoch 295/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.7832e-06 - val_loss: 2.4676e-06
# Epoch 296/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.6092e-06 - val_loss: 2.2809e-06
# Epoch 297/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.4458e-06 - val_loss: 2.0607e-06
# Epoch 298/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2841e-06 - val_loss: 1.8355e-06
# Epoch 299/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1312e-06 - val_loss: 1.6628e-06
# Epoch 300/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.9843e-06 - val_loss: 1.5177e-06
# Epoch 301/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.8345e-06 - val_loss: 1.3241e-06
# Epoch 302/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.6986e-06 - val_loss: 1.2653e-06
# Epoch 303/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.5663e-06 - val_loss: 1.1482e-06
# Epoch 304/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.4468e-06 - val_loss: 1.1570e-06
# Epoch 305/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.3237e-06 - val_loss: 1.1290e-06
# Epoch 306/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.2075e-06 - val_loss: 1.2722e-06
# Epoch 307/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.1082e-06 - val_loss: 1.4760e-06
# Epoch 308/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.0072e-06 - val_loss: 1.7263e-06
# Epoch 309/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.9077e-06 - val_loss: 2.0306e-06
# Epoch 310/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.8071e-06 - val_loss: 2.4261e-06
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# MSE val: 0.0000
# MAE val: 0.0008
# R2 val: 0.9994
# MAPE val: 0.0011
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step
# MSE test: 0.0000
# MAE test: 0.0014
# R2 test: 0.9895
# MAPE test: 0.0027

# %%
# График лосса

train_loss = history.history['loss']
val_loss = history.history['val_loss']

fig, ax = plt.subplots()
ax.plot(train_loss, label='Training loss')
ax.plot(val_loss, label='Validation loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.legend()
plt.show()

# %%
# сохранение модели с помощью метода save()

# lstm_model_v1.keras - 1 признак Recovered_vol
model_filename = '/home/ranksjupyter/notebooks/Ranks/sector_models/vols_pred/lstm_model_v1.keras'
model.save(model_filename)

# %%
model = tf.keras.models.load_model('lstm_model_v1.keras', custom_objects={'custom_logcosh': custom_logcosh})

# Get the configuration of the model
# config = model.get_config()
# config

# %%
# Предсказание значений на валидационной выборке
val_pred = model.predict(X_val)
print(f'MSE val: {mean_squared_error(y_val, val_pred):.4f}')
print(f'MAE val: {mean_absolute_error(y_val, val_pred):.4f}')
print(f'R2 val: {r2_score(y_val, val_pred):.4f}')
print(f'MAPE val: {mean_absolute_percentage_error(y_val, val_pred):.4f}')

# Предсказание значений на тестовой выборке
y_pred = model.predict(X_test)
print(f'MSE test: {mean_squared_error(y_test, y_pred):.4f}')
print(f'MAE test: {mean_absolute_error(y_test, y_pred):.4f}')
print(f'R2 test: {r2_score(y_test, y_pred):.4f}')
print(f'MAPE test: {mean_absolute_percentage_error(y_test, y_pred):.4f}')

# %%
plt.figure(figsize=(10, 5))
plt.plot(test_sample.index, y_test, label='Тестовая выборка', color='cyan', linewidth=1)
plt.plot(test_sample.index, y_pred, label='Предсказания на тестовой выборке', color='black', linewidth=1, linestyle='--')
plt.xlabel('Дата')
plt.ylabel('S&P 500 Реализованная волатильность \n после предобработки')
plt.legend()

plt.savefig('test_predictions.svg', format='svg', dpi=1000)

plt.show()

# %%
# # Построение графика val выборки и прогнозов

# plt.figure(figsize=(10, 5))
# plt.plot(y_val, label='Validation data')
# plt.plot(val_pred, label='Validation Predictions')
# plt.title('Validation data and predictions')
# plt.xlabel('Samples')
# plt.ylabel('Values')
# plt.legend()
# plt.show()

# %%
# keras.losses.log_cosh

n_units = 4
dropout_rate = 0.0
recurrent_dropout_rate = 0.0
activation = 'tanh'
seed = 1
input_model = (X_train.shape[1], X_train.shape[2])

model = Sequential()

model.add(LSTM(
    n_units,
    activation=activation, 
    return_sequences=True,
    input_shape=input_model,
    recurrent_dropout=recurrent_dropout_rate,
    seed=seed,
))
model.add(Dropout(dropout_rate))

model.add(LSTM(
    n_units,
    activation=activation,
    return_sequences=True,
    recurrent_dropout=recurrent_dropout_rate,
    seed=seed
))
model.add(Dropout(dropout_rate))

model.add(LSTM(
    n_units,
    activation=activation,
    recurrent_dropout=recurrent_dropout_rate,
    seed=seed
))
model.add(Dropout(dropout_rate))

model.add(Dense(1))
model.add(Activation('linear'))

early_stopping = EarlyStopping(monitor='val_loss', patience=5)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=keras.losses.log_cosh) # keras.losses.log_cosh

history = model.fit(X_train,
                    y_train,
                    epochs=500,
                    batch_size=4,
                    validation_data=(X_val, y_val),
                    verbose=1,
                    shuffle=False,
                    callbacks=[early_stopping])

# Предсказание значений на валидационной выборке
val_pred_log_cosh = model.predict(X_val)
print(f'MSE val: {mean_squared_error(y_val, val_pred_log_cosh):.4f}')
print(f'MAE val: {mean_absolute_error(y_val, val_pred_log_cosh):.4f}')
print(f'R2 val: {r2_score(y_val, val_pred):.4f}')
print(f'MAPE val: {mean_absolute_percentage_error(y_val, val_pred):.4f}')

# Предсказание значений на тестовой выборке
y_pred_log_cosh = model.predict(X_test)
print(f'MSE test: {mean_squared_error(y_test, y_pred_log_cosh):.4f}')
print(f'MAE test: {mean_absolute_error(y_test, y_pred_log_cosh):.4f}')
print(f'R2 test: {r2_score(y_test, y_pred_log_cosh):.4f}')
print(f'MAPE test: {mean_absolute_percentage_error(y_test, y_pred_log_cosh):.4f}')
# Out:
# Epoch 1/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2188 - val_loss: 0.1617
# Epoch 2/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1385 - val_loss: 0.0653
# Epoch 3/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0448 - val_loss: 0.0055
# Epoch 4/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 5/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 6/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 7/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 8/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 9/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 10/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 11/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 12/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 13/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 14/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 15/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 16/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 17/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0012 - val_loss: 9.9058e-04
# Epoch 18/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0011 - val_loss: 9.7565e-04
# Epoch 19/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0011 - val_loss: 9.5951e-04
# Epoch 20/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0011 - val_loss: 9.4166e-04
# Epoch 21/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0011 - val_loss: 9.2154e-04
# Epoch 22/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0011 - val_loss: 8.9876e-04
# Epoch 23/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 8.7337e-04
# Epoch 24/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 8.4586e-04
# Epoch 25/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.6986e-04 - val_loss: 8.1690e-04
# Epoch 26/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3649e-04 - val_loss: 7.8700e-04
# Epoch 27/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.0217e-04 - val_loss: 7.5648e-04
# Epoch 28/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.6718e-04 - val_loss: 7.2547e-04
# Epoch 29/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.3166e-04 - val_loss: 6.9399e-04
# Epoch 30/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.9560e-04 - val_loss: 6.6202e-04
# Epoch 31/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.5896e-04 - val_loss: 6.2948e-04
# Epoch 32/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.2166e-04 - val_loss: 5.9631e-04
# Epoch 33/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.8363e-04 - val_loss: 5.6244e-04
# Epoch 34/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.4478e-04 - val_loss: 5.2780e-04
# Epoch 35/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.0503e-04 - val_loss: 4.9234e-04
# Epoch 36/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.6434e-04 - val_loss: 4.5602e-04
# Epoch 37/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.2265e-04 - val_loss: 4.1884e-04
# Epoch 38/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.7996e-04 - val_loss: 3.8084e-04
# Epoch 39/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3632e-04 - val_loss: 3.4207e-04
# Epoch 40/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.9183e-04 - val_loss: 3.0271e-04
# Epoch 41/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.4668e-04 - val_loss: 2.6303e-04
# Epoch 42/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.0120e-04 - val_loss: 2.2341e-04
# Epoch 43/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5586e-04 - val_loss: 1.8443e-04
# Epoch 44/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.1136e-04 - val_loss: 1.4689e-04
# Epoch 45/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.6864e-04 - val_loss: 1.1183e-04
# Epoch 46/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.2890e-04 - val_loss: 8.0529e-05
# Epoch 47/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3617e-05 - val_loss: 5.4397e-05
# Epoch 48/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.4318e-05 - val_loss: 3.4723e-05
# Epoch 49/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2282e-05 - val_loss: 2.2056e-05
# Epoch 50/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.7910e-05 - val_loss: 1.5571e-05
# Epoch 51/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.0176e-05 - val_loss: 1.3216e-05
# Epoch 52/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.6825e-05 - val_loss: 1.2762e-05
# Epoch 53/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.5584e-05 - val_loss: 1.2821e-05
# Epoch 54/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.5116e-05 - val_loss: 1.2904e-05
# Epoch 55/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4893e-05 - val_loss: 1.2932e-05
# Epoch 56/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4747e-05 - val_loss: 1.2916e-05
# Epoch 57/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4627e-05 - val_loss: 1.2878e-05
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# MSE val: 0.0000
# MAE val: 0.0046
# R2 val: 0.9994
# MAPE val: 0.0011
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step
# MSE test: 0.0002
# MAE test: 0.0063
# R2 test: 0.9346
# MAPE test: 0.0104

# %%
# LSTM quantile logcosh
quan = []
for q in np.arange(0, 1.1, 0.1):
    quantile_error = np.abs(np.quantile(y_test, q) - np.quantile(y_pred, q))
    quan.append(quantile_error)
quan_df = pd.DataFrame(quan, columns=['LSTM quantile logcosh'])
index = np.arange(0, len(quan_df)*0.1, 0.1)
quan_df.set_index(index, inplace=True)

# LSTM logcosh
quan_log_cosh = []
for q in np.arange(0, 1.1, 0.1):
    quantile_error = np.abs(np.quantile(y_test, q) - np.quantile(y_pred_log_cosh, q))
    quan_log_cosh.append(quantile_error)
    
quan_df_log_cosh = pd.DataFrame(quan_log_cosh, columns=['LSTM logcosh'])
index = np.arange(0, len(quan_df_log_cosh)*0.1, 0.1)
quan_df_log_cosh.set_index(index, inplace=True)

quan_df['LSTM logcosh'] = quan_df_log_cosh

plt.figure(figsize=(5, 4))
plt.plot(quan_df['LSTM quantile logcosh'], color='black', label='LSTM Quantile Log Cosh')
plt.plot(quan_df['LSTM logcosh'], color='red', label='LSTM Log Cosh', linestyle='--')
plt.legend()
plt.xlabel('Квантиль')
plt.ylabel('Значение ошибки')

plt.savefig('lstm_q_errors.svg', format='svg')

plt.show()
