# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import keras
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, Dropout, BatchNormalization, Activation
from keras.models import Model, Sequential
from keras.regularizers import l1_l2
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer, LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error, explained_variance_score
from sklearn.ensemble import IsolationForest
import tensorflow as tf

from sklearn.preprocessing import PowerTransformer

import warnings
warnings.filterwarnings("ignore")

# %%
vix_data = yf.download('^VIX', start='2008-01-01')
vix_data['VIX_close'] = vix_data['Adj Close']

vol_df = pd.read_csv('volatility_df.csv', 
                     parse_dates=['Date'], index_col='Date')

volatility_df = pd.merge_asof(vol_df, vix_data['VIX_close'], left_index=True, right_index=True, direction='nearest')
volatility_df = volatility_df.set_index(vol_df.index)
volatility_df.isna().sum()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Recovered_vol                    0
# Risk_premium                     0
# Risk_preference                  0
# Risk_neutral_skewness            0
# Risk_neutral_kurtosis            0
# Recovered_skewness               0
# Recovered_kurtosis               0
# USA_10_y_treasuries              0
# Effective_Fed_Funds_Rate_true    0
# Consumer_Price_Index_true        0
# Producer_Price_Index_true        0
# Unemployment_Rate_true           0
# GDP_true                         0
# Industrial_Production_true       0
# Mortgage_Rates_true              0
# Realized_Volatility              0
# VIX_close                        0
# dtype: int64

# %%
volatility_df = volatility_df[['Recovered_vol',
                               'Risk_premium', 'Risk_preference',
                               'VIX_close', 'Realized_Volatility']]

volatility_df = volatility_df.replace([0], 1e-6)

volatility_df = volatility_df / volatility_df.shift(1) - 1

lag = -5
volatility_df[f'Realized_Volatility_(t+{abs(lag)})'] = volatility_df['Realized_Volatility'].shift(lag)
volatility_df = volatility_df.dropna()

print(len(volatility_df))
volatility_df.head(10)
# Out:
# 3357
#             Recovered_vol  Risk_premium  Risk_preference  VIX_close  \
# Date
# 2010-01-05      -0.024188     -0.842892         0.119724  -0.034431
# 2010-01-06       0.001425      0.247562         0.002371  -0.009819
# 2010-01-07       0.007015      0.222614         0.014305  -0.005219
# 2010-01-08       0.030061     -0.979034        -0.110890  -0.048793
# 2010-01-11       0.030583     98.432695         0.030537  -0.031991
# 2010-01-12      -0.037054      0.438333        -0.051378   0.039886
# 2010-01-13       0.161288     -1.216182         0.260483  -0.021918
# 2010-01-14       0.012751      0.520871         0.022884  -0.012325
# 2010-01-15      -0.231002     -4.854506        -0.308144   0.015882
# 2010-01-19       0.041342     -0.849285         0.311218  -0.018425
#
#             Realized_Volatility  Realized_Volatility_(t+5)
# Date
# 2010-01-05            -0.029937                   0.031692
# 2010-01-06            -0.015344                   0.029962
# 2010-01-07             0.005156                  -0.022161
# 2010-01-08            -0.052279                   0.046408
# 2010-01-11            -0.006034                   0.073188
# 2010-01-12             0.031692                  -0.011969
# 2010-01-13             0.029962                   0.137014
# 2010-01-14            -0.022161                   0.125819
# 2010-01-15             0.046408                   0.002256
# 2010-01-19             0.073188                   0.003335

# %%
# Стандартизация, нормализация, замена выбросов медианой

values_clear = volatility_df.copy()

train_size = int(len(values_clear) * 0.7)
val_size = int(len(values_clear) * 0.15)
test_size = len(values_clear) - train_size - val_size

train = values_clear.iloc[:train_size]
val = values_clear.iloc[train_size:train_size + val_size]
test = values_clear.iloc[train_size + val_size:]

# Обучаем стандартизатор, нормализатор и изолейшн форест на тренировочных данных
transformer = PowerTransformer(method='yeo-johnson')
transformer.fit(train)
train_transformed = transformer.transform(train)

scaler = MinMaxScaler(feature_range=(1e-6, 1))
scaler.fit(train_transformed)
train_scaled = scaler.transform(train_transformed)

isolation_forest = IsolationForest(n_estimators=1000, contamination='auto') # 0.01
isolation_forest.fit(train_scaled)

normalizer = Normalizer()
normalizer.fit(train_scaled)

# Применяем стандартизатор, нормализатор и изолейшн форест на тренировочных, валидационных и тестовых данных
train_isolation_forest = isolation_forest.predict(train_scaled)
train_normalized = normalizer.transform(train_scaled)

val_transformed = transformer.transform(val)
val_scaled = scaler.transform(val_transformed)
val_isolation_forest = isolation_forest.predict(val_scaled)
val_normalized = normalizer.transform(val_scaled)

test_transformed = transformer.transform(test)
test_scaled = scaler.transform(test_transformed)
test_isolation_forest = isolation_forest.predict(test_scaled)
test_normalized = normalizer.transform(test_scaled)

# Считаем метрику
train_values = np.median(train_normalized, axis=0)
val_values = np.median(val_normalized, axis=0)
test_values = np.median(test_normalized, axis=0)

# Заполняем выбросы медианой
train_normalized[train_isolation_forest == -1] = train_values
val_normalized[val_isolation_forest == -1] = val_values
test_normalized[test_isolation_forest == -1] = test_values

y_train = train_normalized[:, -1:]
y_train = np.squeeze(y_train)
X_train = np.delete(train_normalized, -1, axis=1)

y_val = val_normalized[:, -1:]
y_val = np.squeeze(y_val)
X_val = np.delete(val_normalized, -1, axis=1)

y_test = test_normalized[:, -1:]
y_test = np.squeeze(y_test)
X_test = np.delete(test_normalized, -1, axis=1)

# Reshape
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_val = X_val.reshape((X_val.shape[0], 1, X_val.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

print(X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape)
# Out:
# (2349, 1, 5) (2349,) (503, 1, 5) (503,) (505, 1, 5) (505,)

# %%
# LSTM

# %%
# custom_logcosh

penalty = 5
quantile_threshold = 75
quantile = tf.constant(np.percentile(y_train, quantile_threshold), dtype=tf.float32)

def custom_logcosh(y_true, y_pred):
    error = y_true - y_pred
    mask = tf.cast(y_true > quantile, tf.float32)
    weighted_error = error * (1 + penalty * mask * (y_true - quantile))
    return tf.reduce_sum(tf.math.log(tf.math.cosh(weighted_error)))

# %%
n_units = 512
dropout_rate = 0.4
activation = 'tanh'

model = Sequential()

model.add(LSTM(
    n_units, 
    activation=activation, 
    return_sequences=True,
    input_shape=(X_train.shape[1], X_train.shape[2])
))
model.add(Dropout(dropout_rate))

model.add(LSTM(
    n_units,
    activation=activation, 
    return_sequences=True
))
model.add(Dropout(dropout_rate))

model.add(LSTM(
    n_units, 
    activation=activation
))
model.add(Dropout(dropout_rate))

model.add(Dense(1))
model.add(Activation('linear'))

early_stopping = EarlyStopping(monitor='val_loss', patience=10)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=custom_logcosh) # keras.losses.log_cosh

history = model.fit(X_train,
                    y_train,
                    epochs=200,
                    batch_size=64,
                    validation_data=(X_val, y_val),
                    verbose=1,
                    shuffle=False,
                    callbacks=[early_stopping])

# Предсказание значений на валидационной выборке
val_pred = model.predict(X_val)
print(f'MSE val: {mean_squared_error(y_val, val_pred):.4f}')
print(f'MAE val: {mean_absolute_error(y_val, val_pred):.4f}')
print(f'R2 val: {r2_score(y_val, val_pred):.4f}')
print(f'MAPE val: {mean_absolute_percentage_error(y_val, val_pred):.4f}')

# Предсказание значений на тестовой выборке
y_pred = model.predict(X_test)
print(f'MSE test: {mean_squared_error(y_test, y_pred):.4f}')
print(f'MAE test: {mean_absolute_error(y_test, y_pred):.4f}')
print(f'R2 test: {r2_score(y_test, y_pred):.4f}')
print(f'MAPE test: {mean_absolute_percentage_error(y_test, y_pred):.4f}')
# Out:
# Epoch 1/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss:
# Epoch 198/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0229 - val_loss: 0.0064
# Epoch 199/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0207 - val_loss: 0.0066
# Epoch 200/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0216 - val_loss: 0.0063
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# MSE val: 0.0002
# MAE val: 0.0086
# R2 val: 0.8242
# MAPE val: 0.0200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE test: 0.0001
# MAE test: 0.0078
# R2 test: 0.8237
# MAPE test: 0.0179

# %%
# сохранение модели с помощью метода save()
model_filename = '/home/ranksjupyter/notebooks/Ranks/sector_models/vols_pred/lstm_model.keras'
model.save(model_filename)

# %%
model = tf.keras.models.load_model('lstm_model.keras', custom_objects={'custom_logcosh': custom_logcosh})

# %%
# График лосса

train_loss = history.history['loss']
val_loss = history.history['val_loss']

fig, ax = plt.subplots()
ax.plot(train_loss, label='Training loss')
ax.plot(val_loss, label='Validation loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.legend()
plt.show()

# %%
# Построение графика тестовой выборки и прогнозов

plt.figure(figsize=(10, 5))
plt.plot(y_test, label='Test data')
plt.plot(y_pred, label='Test Predictions')
plt.title('Test data and predictions')
plt.xlabel('Samples')
plt.ylabel('Values') 
plt.legend()
plt.show()

# %%
# Построение графика val выборки и прогнозов

plt.figure(figsize=(10, 5))
plt.plot(y_val, label='Validation data')
plt.plot(val_pred, label='Validation Predictions')
plt.title('Validation data and predictions')
plt.xlabel('Samples')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Вычисление квантильных ошибок
quan = []
for q in np.arange(0, 1.1, 0.1):
    quantile_error = np.abs(np.quantile(y_test, q) - np.quantile(y_pred, q))
    quan.append(quantile_error)
    print(f'Ошибка для квантиля {q.round(2)}: {quantile_error.round(3)}')
# Out:
# Ошибка для квантиля 0.0: 0.064
# Ошибка для квантиля 0.1: 0.003
# Ошибка для квантиля 0.2: 0.002
# Ошибка для квантиля 0.3: 0.001
# Ошибка для квантиля 0.4: 0.003
# Ошибка для квантиля 0.5: 0.004
# Ошибка для квантиля 0.6: 0.003
# Ошибка для квантиля 0.7: 0.004
# Ошибка для квантиля 0.8: 0.005
# Ошибка для квантиля 0.9: 0.004
# Ошибка для квантиля 1.0: 0.009

# %%
# График квантильной ошибки
quan_df = pd.DataFrame(quan, columns=['quantile error'])

index = np.arange(0, len(quan_df)*0.1, 0.1)
quan_df.set_index(index, inplace=True)

plt.figure(figsize=(10, 5))
plt.plot(quan_df)
plt.show()

# %%
# keras.losses.log_cosh

n_units = 512
dropout_rate = 0.4
activation = 'tanh'

model = Sequential()

model.add(LSTM(
    n_units, 
    activation=activation, 
    return_sequences=True,
    input_shape=(X_train.shape[1], X_train.shape[2])
))
model.add(Dropout(dropout_rate))

model.add(LSTM(
    n_units,
    activation=activation, 
    return_sequences=True
))
model.add(Dropout(dropout_rate))

model.add(LSTM(
    n_units, 
    activation=activation
))
model.add(Dropout(dropout_rate))

model.add(Dense(1))
model.add(Activation('linear'))

early_stopping = EarlyStopping(monitor='val_loss', patience=10)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=keras.losses.log_cosh) # keras.losses.log_cosh

history = model.fit(X_train,
                    y_train,
                    epochs=200,
                    batch_size=64,
                    validation_data=(X_val, y_val),
                    verbose=1,
                    shuffle=False,
                    callbacks=[early_stopping])

# Предсказание значений на валидационной выборке
val_pred = model.predict(X_val)
print(f'MSE val: {mean_squared_error(y_val, val_pred):.4f}')
print(f'MAE val: {mean_absolute_error(y_val, val_pred):.4f}')
print(f'R2 val: {r2_score(y_val, val_pred):.4f}')
print(f'MAPE val: {mean_absolute_percentage_error(y_val, val_pred):.4f}')

# Предсказание значений на тестовой выборке
y_pred = model.predict(X_test)
print(f'MSE test: {mean_squared_error(y_test, y_pred):.4f}')
print(f'MAE test: {mean_absolute_error(y_test, y_pred):.4f}')
print(f'R2 test: {r2_score(y_test, y_pred):.4f}')
print(f'MAPE test: {mean_absolute_percentage_error(y_test, y_pred):.4f}')
# Out:
# Epoch 1/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0873 - val_loss: 0.0545
# Epoch 2/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0349 - val_loss: 0.0018
# Epoch 3/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0020 - val_loss: 6.7408e-04
# Epoch 4/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0013 - val_loss: 6.6666e-04
# Epoch 5/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0012 - val_loss: 6.4596e-04
# Epoch 6/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0012 - val_loss: 6.3445e-04
# Epoch 7/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0012 - val_loss: 6.2687e-04
# Epoch 8/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0012 - val_loss: 6.2121e-04
# Epoch 9/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0012 - val_loss: 6.1094e-04
# Epoch 10/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0012 - val_loss: 6.0667e-04
# Epoch 11/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0011 - val_loss: 6.0441e-04
# Epoch 12/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0011 - val_loss: 5.9575e-04
# Epoch 13/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0011 - val_loss: 5.8459e-04
# Epoch 14/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0011 - val_loss: 5.8078e-04
# Epoch 15/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0012 - val_loss: 5.6384e-04
# Epoch 16/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0011 - val_loss: 5.5162e-04
# Epoch 17/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0011 - val_loss: 5.4267e-04
# Epoch 18/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0012 - val_loss: 5.3742e-04
# Epoch 19/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0011 - val_loss: 5.2817e-04
# Epoch 20/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0011 - val_loss: 5.1645e-04
# Epoch 21/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0010 - val_loss: 5.0654e-04
# Epoch 22/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0011 - val_loss: 5.0141e-04
# Epoch 23/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.7918e-04 - val_loss: 4.9062e-04
# Epoch 24/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.9200e-04 - val_loss: 4.8312e-04
# Epoch 25/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0010 - val_loss: 4.7382e-04
# Epoch 26/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.8367e-04 - val_loss: 4.8020e-04
# Epoch 27/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0010 - val_loss: 4.6507e-04
# Epoch 28/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.9756e-04 - val_loss: 4.4873e-04
# Epoch 29/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.4300e-04 - val_loss: 4.3627e-04
# Epoch 30/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.7437e-04 - val_loss: 4.2823e-04
# Epoch 31/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.2943e-04 - val_loss: 4.2292e-04
# Epoch 32/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.6175e-04 - val_loss: 4.1478e-04
# Epoch 33/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.4676e-04 - val_loss: 4.1083e-04
# Epoch 34/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.0407e-04 - val_loss: 4.1388e-04
# Epoch 35/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.9165e-04 - val_loss: 3.9454e-04
# Epoch 36/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.7745e-04 - val_loss: 3.8811e-04
# Epoch 37/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.6534e-04 - val_loss: 3.8674e-04
# Epoch 38/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.3444e-04 - val_loss: 3.7911e-04
# Epoch 39/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.2454e-04 - val_loss: 3.7502e-04
# Epoch 40/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.5900e-04 - val_loss: 3.7515e-04
# Epoch 41/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.9932e-04 - val_loss: 3.6724e-04
# Epoch 42/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.1698e-04 - val_loss: 3.6382e-04
# Epoch 43/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.2561e-04 - val_loss: 3.6097e-04
# Epoch 44/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.5905e-04 - val_loss: 3.5913e-04
# Epoch 45/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.0027e-04 - val_loss: 3.6779e-04
# Epoch 46/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.4411e-04 - val_loss: 3.5390e-04
# Epoch 47/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.4405e-04 - val_loss: 3.5268e-04
# Epoch 48/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.4392e-04 - val_loss: 3.6641e-04
# Epoch 49/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.7724e-04 - val_loss: 3.5007e-04
# Epoch 50/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.5520e-04 - val_loss: 3.4861e-04
# Epoch 51/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.4587e-04 - val_loss: 3.4748e-04
# Epoch 52/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.3187e-04 - val_loss: 3.8946e-04
# Epoch 53/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.3892e-04 - val_loss: 3.5514e-04
# Epoch 54/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.0083e-04 - val_loss: 3.5097e-04
# Epoch 55/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.4807e-04 - val_loss: 3.4290e-04
# Epoch 56/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.2810e-04 - val_loss: 3.6013e-04
# Epoch 57/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.1300e-04 - val_loss: 3.4838e-04
# Epoch 58/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.0889e-04 - val_loss: 3.4385e-04
# Epoch 59/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.4765e-04 - val_loss: 3.4296e-04
# Epoch 60/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.1490e-04 - val_loss: 3.4583e-04
# Epoch 61/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.2125e-04 - val_loss: 3.3687e-04
# Epoch 62/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.2572e-04 - val_loss: 3.3981e-04
# Epoch 63/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.9997e-04 - val_loss: 3.3385e-04
# Epoch 64/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.0105e-04 - val_loss: 3.3799e-04
# Epoch 65/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.9778e-04 - val_loss: 3.3344e-04
# Epoch 66/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.6449e-04 - val_loss: 3.3459e-04
# Epoch 67/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.9422e-04 - val_loss: 3.2935e-04
# Epoch 68/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.7995e-04 - val_loss: 3.3009e-04
# Epoch 69/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 6.6343e-04 - val_loss: 3.2661e-04
# Epoch 70/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.9582e-04 - val_loss: 3.2706e-04
# Epoch 71/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.7152e-04 - val_loss: 3.2586e-04
# Epoch 72/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.5158e-04 - val_loss: 3.2360e-04
# Epoch 73/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.4782e-04 - val_loss: 3.2244e-04
# Epoch 74/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.3315e-04 - val_loss: 3.2213e-04
# Epoch 75/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.0826e-04 - val_loss: 3.2332e-04
# Epoch 76/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.5976e-04 - val_loss: 3.2341e-04
# Epoch 77/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.5064e-04 - val_loss: 3.2549e-04
# Epoch 78/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.5442e-04 - val_loss: 3.2545e-04
# Epoch 79/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.5023e-04 - val_loss: 3.1904e-04
# Epoch 80/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.6981e-04 - val_loss: 3.3109e-04
# Epoch 81/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.2557e-04 - val_loss: 3.2051e-04
# Epoch 82/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.1769e-04 - val_loss: 3.1325e-04
# Epoch 83/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.9059e-04 - val_loss: 3.1242e-04
# Epoch 84/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.9712e-04 - val_loss: 3.1150e-04
# Epoch 85/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.0765e-04 - val_loss: 3.1034e-04
# Epoch 86/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.1509e-04 - val_loss: 3.1110e-04
# Epoch 87/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.0508e-04 - val_loss: 3.0793e-04
# Epoch 88/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.9797e-04 - val_loss: 3.1477e-04
# Epoch 89/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.8230e-04 - val_loss: 3.0618e-04
# Epoch 90/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.7259e-04 - val_loss: 3.0429e-04
# Epoch 91/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.5280e-04 - val_loss: 3.0546e-04
# Epoch 92/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.6749e-04 - val_loss: 3.0643e-04
# Epoch 93/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.6433e-04 - val_loss: 3.1080e-04
# Epoch 94/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.8416e-04 - val_loss: 3.1261e-04
# Epoch 95/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.6834e-04 - val_loss: 3.0109e-04
# Epoch 96/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.7508e-04 - val_loss: 3.0100e-04
# Epoch 97/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.5276e-04 - val_loss: 2.9866e-04
# Epoch 98/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 5.6697e-04 - val_loss: 2.9853e-04
# Epoch 99/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.4727e-04 - val_loss: 2.9782e-04
# Epoch 100/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.6119e-04 - val_loss: 3.0067e-04
# Epoch 101/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.2648e-04 - val_loss: 2.9533e-04
# Epoch 102/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.6071e-04 - val_loss: 3.0266e-04
# Epoch 103/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.3143e-04 - val_loss: 2.9469e-04
# Epoch 104/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.3433e-04 - val_loss: 3.1083e-04
# Epoch 105/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.2310e-04 - val_loss: 2.9257e-04
# Epoch 106/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.9107e-04 - val_loss: 2.9221e-04
# Epoch 107/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.2241e-04 - val_loss: 2.9212e-04
# Epoch 108/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.0555e-04 - val_loss: 2.9142e-04
# Epoch 109/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.9332e-04 - val_loss: 2.9091e-04
# Epoch 110/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.2748e-04 - val_loss: 2.9135e-04
# Epoch 111/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.2050e-04 - val_loss: 2.9171e-04
# Epoch 112/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.1990e-04 - val_loss: 2.8975e-04
# Epoch 113/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.8702e-04 - val_loss: 2.8960e-04
# Epoch 114/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.8668e-04 - val_loss: 2.8936e-04
# Epoch 115/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.0785e-04 - val_loss: 2.8740e-04
# Epoch 116/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.6217e-04 - val_loss: 2.8998e-04
# Epoch 117/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.7280e-04 - val_loss: 2.9699e-04
# Epoch 118/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.6890e-04 - val_loss: 2.8829e-04
# Epoch 119/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.8272e-04 - val_loss: 2.8714e-04
# Epoch 120/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.8506e-04 - val_loss: 2.8572e-04
# Epoch 121/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.6926e-04 - val_loss: 2.8658e-04
# Epoch 122/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.7279e-04 - val_loss: 2.8940e-04
# Epoch 123/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.6041e-04 - val_loss: 2.8828e-04
# Epoch 124/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.5891e-04 - val_loss: 2.8772e-04
# Epoch 125/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.6684e-04 - val_loss: 2.9503e-04
# Epoch 126/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.7379e-04 - val_loss: 2.9141e-04
# Epoch 127/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.6348e-04 - val_loss: 2.8956e-04
# Epoch 128/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 4.6407e-04 - val_loss: 2.9243e-04
# Epoch 129/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 4.7206e-04 - val_loss: 2.8684e-04
# Epoch 130/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.6678e-04 - val_loss: 2.8217e-04
# Epoch 131/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 4.4617e-04 - val_loss: 2.9954e-04
# Epoch 132/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.3625e-04 - val_loss: 2.8543e-04
# Epoch 133/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 4.4540e-04 - val_loss: 2.8444e-04
# Epoch 134/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 4.4124e-04 - val_loss: 2.9505e-04
# Epoch 135/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.1761e-04 - val_loss: 2.8108e-04
# Epoch 136/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 4.2942e-04 - val_loss: 2.8041e-04
# Epoch 137/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 4.5442e-04 - val_loss: 2.7839e-04
# Epoch 138/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 4.4498e-04 - val_loss: 2.7766e-04
# Epoch 139/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 4.3525e-04 - val_loss: 2.8110e-04
# Epoch 140/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.5732e-04 - val_loss: 2.8470e-04
# Epoch 141/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.4786e-04 - val_loss: 2.7369e-04
# Epoch 142/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.2735e-04 - val_loss: 2.8594e-04
# Epoch 143/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 4.3910e-04 - val_loss: 2.7332e-04
# Epoch 144/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.3176e-04 - val_loss: 2.7387e-04
# Epoch 145/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 4.3406e-04 - val_loss: 2.7571e-04
# Epoch 146/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 4.1551e-04 - val_loss: 2.7321e-04
# Epoch 147/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 4.1825e-04 - val_loss: 2.8117e-04
# Epoch 148/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 4.1519e-04 - val_loss: 2.7807e-04
# Epoch 149/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 4.0530e-04 - val_loss: 2.8264e-04
# Epoch 150/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.0759e-04 - val_loss: 2.7763e-04
# Epoch 151/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.0270e-04 - val_loss: 2.6988e-04
# Epoch 152/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.1772e-04 - val_loss: 2.6811e-04
# Epoch 153/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.0942e-04 - val_loss: 2.6965e-04
# Epoch 154/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.2120e-04 - val_loss: 2.8325e-04
# Epoch 155/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.1160e-04 - val_loss: 2.6513e-04
# Epoch 156/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 3.8645e-04 - val_loss: 2.6550e-04
# Epoch 157/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.0847e-04 - val_loss: 2.6268e-04
# Epoch 158/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 4.0856e-04 - val_loss: 2.6298e-04
# Epoch 159/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 4.0129e-04 - val_loss: 2.6139e-04
# Epoch 160/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 3.8730e-04 - val_loss: 2.5602e-04
# Epoch 161/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 3.7429e-04 - val_loss: 2.5424e-04
# Epoch 162/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 3.8603e-04 - val_loss: 2.5550e-04
# Epoch 163/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 3.8585e-04 - val_loss: 2.5219e-04
# Epoch 164/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 4.0027e-04 - val_loss: 2.5002e-04
# Epoch 165/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 3.8088e-04 - val_loss: 2.5065e-04
# Epoch 166/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 3.6927e-04 - val_loss: 2.4628e-04
# Epoch 167/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.9049e-04 - val_loss: 2.5186e-04
# Epoch 168/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 3.5382e-04 - val_loss: 2.4337e-04
# Epoch 169/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 3.8210e-04 - val_loss: 2.5423e-04
# Epoch 170/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 3.8141e-04 - val_loss: 2.3852e-04
# Epoch 171/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 3.8250e-04 - val_loss: 2.4546e-04
# Epoch 172/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 3.7231e-04 - val_loss: 2.3479e-04
# Epoch 173/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 3.8236e-04 - val_loss: 2.3511e-04
# Epoch 174/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 3.6911e-04 - val_loss: 2.3302e-04
# Epoch 175/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 3.8811e-04 - val_loss: 2.2787e-04
# Epoch 176/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 3.5120e-04 - val_loss: 2.4014e-04
# Epoch 177/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 3.6071e-04 - val_loss: 2.3409e-04
# Epoch 178/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 3.6059e-04 - val_loss: 2.2238e-04
# Epoch 179/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 3.6257e-04 - val_loss: 2.2760e-04
# Epoch 180/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 3.4376e-04 - val_loss: 2.2658e-04
# Epoch 181/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 3.7141e-04 - val_loss: 2.1872e-04
# Epoch 182/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 3.7051e-04 - val_loss: 2.2630e-04
# Epoch 183/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 3.5703e-04 - val_loss: 2.1863e-04
# Epoch 184/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 3.3795e-04 - val_loss: 2.1089e-04
# Epoch 185/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 3.5106e-04 - val_loss: 2.1381e-04
# Epoch 186/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 3.3699e-04 - val_loss: 2.0761e-04
# Epoch 187/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 3.3443e-04 - val_loss: 2.0492e-04
# Epoch 188/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 3.6745e-04 - val_loss: 2.1077e-04
# Epoch 189/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 3.4533e-04 - val_loss: 2.0031e-04
# Epoch 190/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 3.5005e-04 - val_loss: 2.0056e-04
# Epoch 191/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 3.3660e-04 - val_loss: 1.9493e-04
# Epoch 192/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 3.2589e-04 - val_loss: 1.9895e-04
# Epoch 193/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 3.4532e-04 - val_loss: 1.9811e-04
# Epoch 194/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 3.5718e-04 - val_loss: 1.8980e-04
# Epoch 195/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 3.4214e-04 - val_loss: 1.8725e-04
# Epoch 196/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 3.2953e-04 - val_loss: 1.8458e-04
# Epoch 197/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 3.3520e-04 - val_loss: 1.8220e-04
# Epoch 198/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - loss: 3.1956e-04 - val_loss: 1.8055e-04
# Epoch 199/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 3.2984e-04 - val_loss: 1.8237e-04
# Epoch 200/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 3.3143e-04 - val_loss: 1.7520e-04
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# MSE val: 0.0004
# MAE val: 0.0101
# R2 val: 0.6358
# MAPE val: 0.0233
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# MSE test: 0.0001
# MAE test: 0.0088
# R2 test: 0.7879
# MAPE test: 0.0201
