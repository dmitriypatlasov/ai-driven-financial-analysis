# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import keras
from keras.optimizers import Adam
from keras.layers import LSTM, Dense, Dropout, BatchNormalization, Activation
from keras.models import Model, Sequential
from keras.regularizers import l1_l2
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler, Normalizer, PowerTransformer
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.ensemble import IsolationForest
import tensorflow as tf
from sklearn.preprocessing import PowerTransformer
from keras.regularizers import l1_l2

import warnings
warnings.filterwarnings("ignore")

np.random.seed(42)
# Out:
# 2024-06-12 19:51:06.145870: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-12 19:51:06.890421: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
vix_data = yf.download('^VIX', start='2008-01-01')
vix_data['VIX_close'] = vix_data['Adj Close']

tnx_data = yf.download('^TNX', start='2008-01-01')
tnx_data['10_Y_close'] = tnx_data['Adj Close'] / 100

irx_data = yf.download('^IRX', start='2008-01-01')
irx_data['3_M_close'] = irx_data['Adj Close'] / 100

vol_df = pd.read_csv('/home/ranksjupyter/notebooks/Ranks/sector_models/vols_pred/volatility_df.csv', 
                     parse_dates=['Date'], index_col='Date')

volatility_df = pd.merge_asof(vol_df, vix_data['VIX_close'], left_index=True, right_index=True, direction='nearest')
volatility_df = pd.merge_asof(volatility_df, tnx_data['10_Y_close'], left_index=True, right_index=True, direction='nearest')
volatility_df = pd.merge_asof(volatility_df, irx_data['3_M_close'], left_index=True, right_index=True, direction='nearest')

volatility_df['Slope'] = volatility_df['10_Y_close'] - volatility_df['3_M_close']
volatility_df = volatility_df.set_index(vol_df.index)
volatility_df.isna().sum()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Recovered_vol                    0
# Risk_premium                     0
# Risk_preference                  0
# Risk_neutral_skewness            0
# Risk_neutral_kurtosis            0
# Recovered_skewness               0
# Recovered_kurtosis               0
# USA_10_y_treasuries              0
# Effective_Fed_Funds_Rate_true    0
# Consumer_Price_Index_true        0
# Producer_Price_Index_true        0
# Unemployment_Rate_true           0
# GDP_true                         0
# Industrial_Production_true       0
# Mortgage_Rates_true              0
# Realized_Volatility              0
# VIX_close                        0
# 10_Y_close                       0
# 3_M_close                        0
# Slope                            0
# dtype: int64

# %%
volatility_df = volatility_df[['Recovered_vol', 'Risk_premium', 'Risk_preference', 
                               'USA_10_y_treasuries', 'Mortgage_Rates_true', 'VIX_close', 
                               'Slope', 'Realized_Volatility']]

volatility_df = volatility_df.replace([0], 1e-6)

volatility_df = volatility_df / volatility_df.shift(1) - 1

lag = -5
volatility_df[f'Realized_Volatility_(t+{abs(lag)})'] = volatility_df['Realized_Volatility'].shift(lag)
volatility_df = volatility_df.dropna()
# volatility_df.drop('Realized_Volatility', axis=1, inplace=True)
print(len(volatility_df))
volatility_df.head(10)
# Out:
# 3357
#             Recovered_vol  Risk_premium  Risk_preference  USA_10_y_treasuries  \
# Date
# 2010-01-05      -0.024188     -0.842892         0.119724            -0.022390
# 2010-01-06       0.001425      0.247562         0.002371             0.014114
# 2010-01-07       0.007015      0.222614         0.014305             0.003676
# 2010-01-08       0.030061     -0.979034        -0.110890            -0.003663
# 2010-01-11       0.030583     98.432695         0.030537             0.002626
# 2010-01-12      -0.037054      0.438333        -0.051378            -0.025930
# 2010-01-13       0.161288     -1.216182         0.260483             0.017209
# 2010-01-14       0.012751      0.520871         0.022884            -0.012953
# 2010-01-15      -0.231002     -4.854506        -0.308144            -0.015533
# 2010-01-19       0.041342     -0.849285         0.311218             0.008433
#
#             Mortgage_Rates_true  VIX_close     Slope  Realized_Volatility  \
# Date
# 2010-01-05             0.000000  -0.034431 -0.024036            -0.029937
# 2010-01-06             0.000000  -0.009819  0.018403            -0.015344
# 2010-01-07             0.000000  -0.005219  0.003720             0.005156
# 2010-01-08             0.000000  -0.048793 -0.002383            -0.052279
# 2010-01-11             0.022267  -0.031991  0.006635            -0.006034
# 2010-01-12             0.000000   0.039886 -0.030055             0.031692
# 2010-01-13             0.000000  -0.021918  0.014678             0.029962
# 2010-01-14             0.000000  -0.012325 -0.011787            -0.022161
# 2010-01-15             0.000000   0.015882 -0.018433             0.046408
# 2010-01-19             0.017822  -0.018425  0.009942             0.073188
#
#             Realized_Volatility_(t+5)
# Date
# 2010-01-05                   0.031692
# 2010-01-06                   0.029962
# 2010-01-07                  -0.022161
# 2010-01-08                   0.046408
# 2010-01-11                   0.073188
# 2010-01-12                  -0.011969
# 2010-01-13                   0.137014
# 2010-01-14                   0.125819
# 2010-01-15                   0.002256
# 2010-01-19                   0.003335

# %%
# Стандартизация, нормализация, замена выбросов медианой

values_clear = volatility_df.copy()

train_size = int(len(values_clear) * 0.7)
val_size = int(len(values_clear) * 0.15)
test_size = len(values_clear) - train_size - val_size

train = values_clear.iloc[:train_size]
val = values_clear.iloc[train_size:train_size + val_size]
test = values_clear.iloc[train_size + val_size:]

# Обучаем стандартизатор, нормализатор и изолейшн форест на тренировочных данных
transformer = PowerTransformer(method='yeo-johnson')
transformer.fit(train)
train_transformed = transformer.transform(train)

scaler = MinMaxScaler(feature_range=(1e-6, 1))
scaler.fit(train_transformed)
train_scaled = scaler.transform(train_transformed)

isolation_forest = IsolationForest(n_estimators=1000, contamination=0.01, random_state=42) # 0.01
isolation_forest.fit(train_scaled)

normalizer = Normalizer()
normalizer.fit(train_scaled)

# Применяем стандартизатор, нормализатор и изолейшн форест на тренировочных, валидационных и тестовых данных
train_isolation_forest = isolation_forest.predict(train_scaled)
train_normalized = normalizer.transform(train_scaled)

val_transformed = transformer.transform(val)
val_scaled = scaler.transform(val_transformed)
val_isolation_forest = isolation_forest.predict(val_scaled)
val_normalized = normalizer.transform(val_scaled)

test_transformed = transformer.transform(test)
test_scaled = scaler.transform(test_transformed)
test_isolation_forest = isolation_forest.predict(test_scaled)
test_normalized = normalizer.transform(test_scaled)

# Считаем метрику
train_values = np.median(train_normalized, axis=0)
val_values = np.median(val_normalized, axis=0)
test_values = np.median(test_normalized, axis=0)

# Заполняем выбросы медианой
train_normalized[train_isolation_forest == -1] = train_values
val_normalized[val_isolation_forest == -1] = val_values
test_normalized[test_isolation_forest == -1] = test_values

y_train = train_normalized[:, -1:]
y_train = np.squeeze(y_train)
X_train = np.delete(train_normalized, -1, axis=1)

y_val = val_normalized[:, -1:]
y_val = np.squeeze(y_val)
X_val = np.delete(val_normalized, -1, axis=1)

y_test = test_normalized[:, -1:]
y_test = np.squeeze(y_test)
X_test = np.delete(test_normalized, -1, axis=1)

# Reshape
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_val = X_val.reshape((X_val.shape[0], 1, X_val.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

print(X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape)
# Out:
# (2349, 1, 8) (2349,) (503, 1, 8) (503,) (505, 1, 8) (505,)

# %%
# LSTM

# %%
# custom_logcosh

penalty = 5
quantile_threshold = 75
quantile = tf.constant(np.percentile(y_train, quantile_threshold), dtype=tf.float32)

def custom_logcosh(y_true, y_pred):
    error = y_true - y_pred
    mask = tf.cast(y_true > quantile, tf.float32)
    weighted_error = error * (1 + penalty * mask * (y_true - quantile))
    return tf.reduce_sum(tf.math.log(tf.math.cosh(weighted_error)))

# %%
n_units = 8
dropout_rate = 0.5
recurrent_dropout_rate = 0.5
activation = 'tanh'
seed = 1
input_model = (X_train.shape[1], X_train.shape[2])
l1_reg = 0.00
l2_reg = 0.00

model = Sequential()

model.add(LSTM(
    n_units,
    activation=activation, 
    return_sequences=True,
    input_shape=input_model,
    recurrent_dropout=recurrent_dropout_rate,
    kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg),
    seed=seed,
))
model.add(Dropout(dropout_rate))

model.add(LSTM(
    n_units,
    activation=activation,
    return_sequences=True,
    recurrent_dropout=recurrent_dropout_rate,
    kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg),
    seed=seed
))
model.add(Dropout(dropout_rate))

model.add(LSTM(
    n_units,
    activation=activation,
    recurrent_dropout=recurrent_dropout_rate,
    kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg),
    seed=seed
))
model.add(Dropout(dropout_rate))

model.add(Dense(1))
model.add(Activation('linear'))

early_stopping = EarlyStopping(monitor='val_loss', patience=10)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=custom_logcosh) # keras.losses.log_cosh

history = model.fit(X_train,
                    y_train,
                    epochs=500,
                    batch_size=4,
                    validation_data=(X_val, y_val),
                    verbose=1,
                    shuffle=False,
                    callbacks=[early_stopping])

# Предсказание значений на валидационной выборке
val_pred = model.predict(X_val)
print(f'MSE val: {mean_squared_error(y_val, val_pred):.4f}')
print(f'MAE val: {mean_absolute_error(y_val, val_pred):.4f}')
print(f'R2 val: {r2_score(y_val, val_pred):.4f}')
print(f'MAPE val: {mean_absolute_percentage_error(y_val, val_pred):.4f}')

# Предсказание значений на тестовой выборке
y_pred = model.predict(X_test)
print(f'MSE test: {mean_squared_error(y_test, y_pred):.4f}')
print(f'MAE test: {mean_absolute_error(y_test, y_pred):.4f}')
print(f'R2 test: {r2_score(y_test, y_pred):.4f}')
print(f'MAPE test: {mean_absolute_percentage_error(y_test, y_pred):.4f}')
# Out:
# Epoch 1/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2505 - val_loss: 0.1204
# Epoch 2/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0945 - val_loss: 0.0188
# Epoch 3/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0384 - val_loss: 0.0072
# Epoch 4/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0298 - val_loss: 0.0055
# Epoch 5/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0221 - val_loss: 0.0038
# Epoch 6/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0174 - val_loss: 0.0027
# Epoch 7/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0142 - val_loss: 0.0026
# Epoch 8/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0124 - val_loss: 0.0024
# Epoch 9/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0098 - val_loss: 0.0022
# Epoch 10/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0092 - val_loss: 0.0020
# Epoch 11/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0069 - val_loss: 0.0019
# Epoch 12/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0064 - val_loss: 0.0019
# Epoch 13/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0054 - val_loss: 0.0018
# Epoch 14/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0045 - val_loss: 0.0018
# Epoch 15/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 16/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 17/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 18/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 19/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 20/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 21/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 22/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 23/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 24/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 25/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 26/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 27/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 28/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 29/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 30/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 31/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 32/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 33/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 34/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 35/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 36/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 37/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 38/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 39/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 40/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 41/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 42/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 43/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 44/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 45/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 46/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 47/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 48/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 49/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 50/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 51/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 52/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 53/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 54/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 55/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 56/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 57/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 58/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 59/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 60/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 61/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 62/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 63/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 64/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 65/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 66/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 67/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 68/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 69/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 70/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 71/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 72/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 73/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 74/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 75/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 76/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 77/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 78/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 79/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 80/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 81/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 82/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 83/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 84/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 85/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 86/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 87/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 88/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 89/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 90/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 91/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 92/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 93/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 94/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 95/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 96/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 97/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 98/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 99/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 100/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 101/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 102/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 103/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 104/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 105/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 106/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 107/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 108/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 109/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 110/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 111/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 112/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 113/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 114/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 115/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 116/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 117/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 118/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 119/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 120/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 121/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 122/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 123/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 124/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 125/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 126/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 127/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 128/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 129/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 130/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 131/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 132/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 133/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 134/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 135/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 136/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 137/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 138/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 139/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 140/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 141/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 142/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 143/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 144/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 145/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 146/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 147/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 148/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 149/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 150/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 151/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 152/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 153/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 154/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 155/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 156/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 157/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 158/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 159/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 160/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 161/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 162/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 163/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 164/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 165/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 166/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 167/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 168/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 169/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 170/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 171/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 172/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 173/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 174/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 175/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 176/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 177/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# MSE val: 0.0006
# MAE val: 0.0160
# R2 val: 0.1638
# MAPE val: 0.0444
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step
# MSE test: 0.0006
# MAE test: 0.0170
# R2 test: 0.4906
# MAPE test: 0.0497

# %%
# График лосса

train_loss = history.history['loss']
val_loss = history.history['val_loss']

fig, ax = plt.subplots()
ax.plot(train_loss, label='Training loss')
ax.plot(val_loss, label='Validation loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.legend()
plt.show()

# %%
# Построение графика тестовой выборки и прогнозов

plt.figure(figsize=(10, 5))
plt.plot(y_test, label='Test data')
plt.plot(y_pred, label='Test Predictions')
plt.title('Test data and predictions')
plt.xlabel('Samples')
plt.ylabel('Values') 
plt.legend()
plt.show()

# %%
# keras.losses.log_cosh

n_units = 8
dropout_rate = 0.5
recurrent_dropout_rate = 0.5
activation = 'tanh'
seed = 1
input_model = (X_train.shape[1], X_train.shape[2])
l1_reg = 0.00
l2_reg = 0.00

model = Sequential()

model.add(LSTM(
    n_units,
    activation=activation, 
    return_sequences=True,
    input_shape=input_model,
    recurrent_dropout=recurrent_dropout_rate,
    kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg),
    seed=seed,
))
model.add(Dropout(dropout_rate))

model.add(LSTM(
    n_units,
    activation=activation,
    return_sequences=True,
    recurrent_dropout=recurrent_dropout_rate,
    kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg),
    seed=seed
))
model.add(Dropout(dropout_rate))

model.add(LSTM(
    n_units,
    activation=activation,
    recurrent_dropout=recurrent_dropout_rate,
    kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg),
    seed=seed
))
model.add(Dropout(dropout_rate))

model.add(Dense(1))
model.add(Activation('linear'))

early_stopping = EarlyStopping(monitor='val_loss', patience=5)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=keras.losses.log_cosh) # keras.losses.log_cosh

history = model.fit(X_train,
                    y_train,
                    epochs=500,
                    batch_size=4,
                    validation_data=(X_val, y_val),
                    verbose=1,
                    shuffle=False,
                    callbacks=[early_stopping])

# Предсказание значений на валидационной выборке
val_pred_log_cosh = model.predict(X_val)
print(f'MSE val: {mean_squared_error(y_val, val_pred_log_cosh):.4f}')
print(f'MAE val: {mean_absolute_error(y_val, val_pred_log_cosh):.4f}')
print(f'R2 val: {r2_score(y_val, val_pred):.4f}')
print(f'MAPE val: {mean_absolute_percentage_error(y_val, val_pred):.4f}')

# Предсказание значений на тестовой выборке
y_pred_log_cosh = model.predict(X_test)
print(f'MSE test: {mean_squared_error(y_test, y_pred_log_cosh):.4f}')
print(f'MAE test: {mean_absolute_error(y_test, y_pred_log_cosh):.4f}')
print(f'R2 test: {r2_score(y_test, y_pred_log_cosh):.4f}')
print(f'MAPE test: {mean_absolute_percentage_error(y_test, y_pred_log_cosh):.4f}')
# Out:
# Epoch 1/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0607 - val_loss: 0.0333
# Epoch 2/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0263 - val_loss: 0.0054
# Epoch 3/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0087 - val_loss: 0.0022
# Epoch 4/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0061 - val_loss: 0.0011
# Epoch 5/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0050 - val_loss: 7.7236e-04
# Epoch 6/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0039 - val_loss: 7.2591e-04
# Epoch 7/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0035 - val_loss: 5.6611e-04
# Epoch 8/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0027 - val_loss: 5.2363e-04
# Epoch 9/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0023 - val_loss: 4.3902e-04
# Epoch 10/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 4.4870e-04
# Epoch 11/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - val_loss: 4.2179e-04
# Epoch 12/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0014 - val_loss: 4.1653e-04
# Epoch 13/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0011 - val_loss: 3.9493e-04
# Epoch 14/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 3.8611e-04
# Epoch 15/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.7358e-04 - val_loss: 3.7923e-04
# Epoch 16/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.3575e-04 - val_loss: 3.7501e-04
# Epoch 17/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.8011e-04 - val_loss: 3.7272e-04
# Epoch 18/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.3532e-04 - val_loss: 3.7207e-04
# Epoch 19/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.8071e-04 - val_loss: 3.6952e-04
# Epoch 20/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.5757e-04 - val_loss: 3.6915e-04
# Epoch 21/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.4974e-04 - val_loss: 3.6894e-04
# Epoch 22/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.4162e-04 - val_loss: 3.6857e-04
# Epoch 23/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.1333e-04 - val_loss: 3.6808e-04
# Epoch 24/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.0745e-04 - val_loss: 3.6776e-04
# Epoch 25/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.9683e-04 - val_loss: 3.6756e-04
# Epoch 26/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.0162e-04 - val_loss: 3.6759e-04
# Epoch 27/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.9595e-04 - val_loss: 3.6701e-04
# Epoch 28/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.8558e-04 - val_loss: 3.6671e-04
# Epoch 29/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.8239e-04 - val_loss: 3.6651e-04
# Epoch 30/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.8245e-04 - val_loss: 3.6623e-04
# Epoch 31/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.8697e-04 - val_loss: 3.6595e-04
# Epoch 32/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.8706e-04 - val_loss: 3.6579e-04
# Epoch 33/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.7958e-04 - val_loss: 3.6526e-04
# Epoch 34/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.7694e-04 - val_loss: 3.6502e-04
# Epoch 35/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.7790e-04 - val_loss: 3.6473e-04
# Epoch 36/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.8004e-04 - val_loss: 3.6454e-04
# Epoch 37/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.7639e-04 - val_loss: 3.6378e-04
# Epoch 38/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.7743e-04 - val_loss: 3.6326e-04
# Epoch 39/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.7247e-04 - val_loss: 3.6239e-04
# Epoch 40/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.7289e-04 - val_loss: 3.6151e-04
# Epoch 41/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.7513e-04 - val_loss: 3.6085e-04
# Epoch 42/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.6825e-04 - val_loss: 3.5980e-04
# Epoch 43/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.6725e-04 - val_loss: 3.5871e-04
# Epoch 44/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.7031e-04 - val_loss: 3.5767e-04
# Epoch 45/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.6384e-04 - val_loss: 3.5697e-04
# Epoch 46/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.6280e-04 - val_loss: 3.5630e-04
# Epoch 47/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.6358e-04 - val_loss: 3.5530e-04
# Epoch 48/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.7013e-04 - val_loss: 3.5452e-04
# Epoch 49/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.6362e-04 - val_loss: 3.5397e-04
# Epoch 50/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.5689e-04 - val_loss: 3.5253e-04
# Epoch 51/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.6041e-04 - val_loss: 3.5236e-04
# Epoch 52/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.5321e-04 - val_loss: 3.5044e-04
# Epoch 53/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.5184e-04 - val_loss: 3.4953e-04
# Epoch 54/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.5835e-04 - val_loss: 3.4846e-04
# Epoch 55/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.5414e-04 - val_loss: 3.4745e-04
# Epoch 56/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.5121e-04 - val_loss: 3.4639e-04
# Epoch 57/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3552e-04 - val_loss: 3.4550e-04
# Epoch 58/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.4874e-04 - val_loss: 3.4468e-04
# Epoch 59/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.5280e-04 - val_loss: 3.4437e-04
# Epoch 60/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.5048e-04 - val_loss: 3.4359e-04
# Epoch 61/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.5557e-04 - val_loss: 3.4197e-04
# Epoch 62/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3862e-04 - val_loss: 3.4112e-04
# Epoch 63/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.5048e-04 - val_loss: 3.4033e-04
# Epoch 64/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.4634e-04 - val_loss: 3.3993e-04
# Epoch 65/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.4193e-04 - val_loss: 3.3906e-04
# Epoch 66/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.4635e-04 - val_loss: 3.3818e-04
# Epoch 67/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.5331e-04 - val_loss: 3.3720e-04
# Epoch 68/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.4739e-04 - val_loss: 3.3561e-04
# Epoch 69/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3924e-04 - val_loss: 3.3459e-04
# Epoch 70/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3866e-04 - val_loss: 3.3370e-04
# Epoch 71/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3351e-04 - val_loss: 3.3228e-04
# Epoch 72/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3871e-04 - val_loss: 3.3119e-04
# Epoch 73/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3331e-04 - val_loss: 3.3027e-04
# Epoch 74/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3060e-04 - val_loss: 3.2957e-04
# Epoch 75/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2856e-04 - val_loss: 3.2891e-04
# Epoch 76/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3349e-04 - val_loss: 3.2794e-04
# Epoch 77/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2622e-04 - val_loss: 3.2702e-04
# Epoch 78/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3860e-04 - val_loss: 3.2682e-04
# Epoch 79/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2980e-04 - val_loss: 3.2504e-04
# Epoch 80/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.4385e-04 - val_loss: 3.2467e-04
# Epoch 81/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2673e-04 - val_loss: 3.2379e-04
# Epoch 82/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.4136e-04 - val_loss: 3.2423e-04
# Epoch 83/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3443e-04 - val_loss: 3.2294e-04
# Epoch 84/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.4166e-04 - val_loss: 3.2138e-04
# Epoch 85/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2269e-04 - val_loss: 3.2057e-04
# Epoch 86/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2553e-04 - val_loss: 3.2060e-04
# Epoch 87/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2446e-04 - val_loss: 3.1960e-04
# Epoch 88/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3721e-04 - val_loss: 3.1928e-04
# Epoch 89/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2760e-04 - val_loss: 3.1805e-04
# Epoch 90/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2759e-04 - val_loss: 3.1755e-04
# Epoch 91/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3050e-04 - val_loss: 3.1704e-04
# Epoch 92/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2737e-04 - val_loss: 3.1571e-04
# Epoch 93/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3268e-04 - val_loss: 3.1690e-04
# Epoch 94/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1133e-04 - val_loss: 3.1459e-04
# Epoch 95/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1605e-04 - val_loss: 3.1431e-04
# Epoch 96/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2292e-04 - val_loss: 3.1374e-04
# Epoch 97/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2539e-04 - val_loss: 3.1331e-04
# Epoch 98/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2614e-04 - val_loss: 3.1301e-04
# Epoch 99/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3048e-04 - val_loss: 3.1307e-04
# Epoch 100/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3063e-04 - val_loss: 3.1224e-04
# Epoch 101/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2129e-04 - val_loss: 3.1133e-04
# Epoch 102/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2252e-04 - val_loss: 3.1100e-04
# Epoch 103/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2194e-04 - val_loss: 3.0989e-04
# Epoch 104/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2180e-04 - val_loss: 3.1098e-04
# Epoch 105/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2908e-04 - val_loss: 3.0969e-04
# Epoch 106/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0858e-04 - val_loss: 3.0861e-04
# Epoch 107/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0847e-04 - val_loss: 3.0749e-04
# Epoch 108/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1083e-04 - val_loss: 3.0671e-04
# Epoch 109/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1575e-04 - val_loss: 3.0704e-04
# Epoch 110/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1827e-04 - val_loss: 3.0616e-04
# Epoch 111/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1834e-04 - val_loss: 3.0616e-04
# Epoch 112/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0812e-04 - val_loss: 3.0672e-04
# Epoch 113/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1284e-04 - val_loss: 3.0539e-04
# Epoch 114/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1671e-04 - val_loss: 3.0515e-04
# Epoch 115/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1610e-04 - val_loss: 3.0489e-04
# Epoch 116/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1467e-04 - val_loss: 3.0436e-04
# Epoch 117/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1835e-04 - val_loss: 3.0378e-04
# Epoch 118/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2024e-04 - val_loss: 3.0416e-04
# Epoch 119/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2257e-04 - val_loss: 3.0360e-04
# Epoch 120/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1061e-04 - val_loss: 3.0305e-04
# Epoch 121/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0897e-04 - val_loss: 3.0361e-04
# Epoch 122/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1056e-04 - val_loss: 3.0258e-04
# Epoch 123/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1306e-04 - val_loss: 3.0192e-04
# Epoch 124/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0954e-04 - val_loss: 3.0281e-04
# Epoch 125/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3502e-04 - val_loss: 3.0206e-04
# Epoch 126/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1019e-04 - val_loss: 3.0084e-04
# Epoch 127/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0881e-04 - val_loss: 3.0062e-04
# Epoch 128/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1408e-04 - val_loss: 3.0127e-04
# Epoch 129/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1076e-04 - val_loss: 2.9976e-04
# Epoch 130/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2296e-04 - val_loss: 3.0032e-04
# Epoch 131/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0868e-04 - val_loss: 2.9963e-04
# Epoch 132/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0752e-04 - val_loss: 2.9900e-04
# Epoch 133/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1298e-04 - val_loss: 2.9919e-04
# Epoch 134/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0799e-04 - val_loss: 2.9797e-04
# Epoch 135/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1787e-04 - val_loss: 2.9835e-04
# Epoch 136/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1253e-04 - val_loss: 2.9793e-04
# Epoch 137/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0706e-04 - val_loss: 2.9820e-04
# Epoch 138/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0272e-04 - val_loss: 2.9709e-04
# Epoch 139/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0282e-04 - val_loss: 2.9695e-04
# Epoch 140/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0320e-04 - val_loss: 2.9668e-04
# Epoch 141/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0591e-04 - val_loss: 2.9679e-04
# Epoch 142/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1466e-04 - val_loss: 2.9653e-04
# Epoch 143/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2455e-04 - val_loss: 2.9736e-04
# Epoch 144/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2769e-04 - val_loss: 2.9715e-04
# Epoch 145/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1022e-04 - val_loss: 2.9762e-04
# Epoch 146/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.9824e-04 - val_loss: 2.9517e-04
# Epoch 147/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1419e-04 - val_loss: 2.9559e-04
# Epoch 148/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0891e-04 - val_loss: 2.9645e-04
# Epoch 149/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0125e-04 - val_loss: 2.9523e-04
# Epoch 150/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0140e-04 - val_loss: 2.9583e-04
# Epoch 151/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.9398e-04 - val_loss: 2.9488e-04
# Epoch 152/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1292e-04 - val_loss: 2.9483e-04
# Epoch 153/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1286e-04 - val_loss: 2.9451e-04
# Epoch 154/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.9832e-04 - val_loss: 2.9495e-04
# Epoch 155/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0388e-04 - val_loss: 2.9408e-04
# Epoch 156/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0820e-04 - val_loss: 2.9365e-04
# Epoch 157/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.9930e-04 - val_loss: 2.9372e-04
# Epoch 158/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.9369e-04 - val_loss: 2.9349e-04
# Epoch 159/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.8543e-04 - val_loss: 2.9329e-04
# Epoch 160/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0013e-04 - val_loss: 2.9280e-04
# Epoch 161/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.9630e-04 - val_loss: 2.9305e-04
# Epoch 162/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0392e-04 - val_loss: 2.9480e-04
# Epoch 163/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1227e-04 - val_loss: 2.9348e-04
# Epoch 164/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0635e-04 - val_loss: 2.9353e-04
# Epoch 165/500
# 588/588 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0059e-04 - val_loss: 2.9425e-04
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# MSE val: 0.0006
# MAE val: 0.0160
# R2 val: 0.1638
# MAPE val: 0.0444
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step
# MSE test: 0.0006
# MAE test: 0.0164
# R2 test: 0.5115
# MAPE test: 0.0484

# %%
# LSTM quantile logcosh
quan = []
for q in np.arange(0, 1.1, 0.1):
    quantile_error = np.abs(np.quantile(y_test, q) - np.quantile(y_pred, q))
    quan.append(quantile_error)
quan_df = pd.DataFrame(quan, columns=['LSTM quantile logcosh'])
index = np.arange(0, len(quan_df)*0.1, 0.1)
quan_df.set_index(index, inplace=True)

# LSTM logcosh
quan_log_cosh = []
for q in np.arange(0, 1.1, 0.1):
    quantile_error = np.abs(np.quantile(y_test, q) - np.quantile(y_pred_log_cosh, q))
    quan_log_cosh.append(quantile_error)

quan_df_log_cosh = pd.DataFrame(quan_log_cosh, columns=['LSTM logcosh'])
index = np.arange(0, len(quan_df_log_cosh)*0.1, 0.1)
quan_df_log_cosh.set_index(index, inplace=True)

quan_df['LSTM logcosh'] = quan_df_log_cosh

plt.figure(figsize=(5, 4))
plt.plot(quan_df['LSTM quantile logcosh'], color='black', label='LSTM Quantile Log Cosh')
plt.plot(quan_df['LSTM logcosh'], color='red', label='LSTM Log Cosh', linestyle='--')
plt.legend()
plt.xlabel('Квантиль')
plt.ylabel('Значение ошибки')

plt.savefig('lstm_q_errors_rob_check.svg', format='svg')

plt.show()
